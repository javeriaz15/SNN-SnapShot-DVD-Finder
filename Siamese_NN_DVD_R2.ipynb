# %% [markdown]
# # One Shot Learning with Siamese Networks
#
# This is the jupyter notebook that accompanies

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Thu May 13 21:50:13 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
train_path = '/content/drive/MyDrive/project/dvdcovers_SNN/data/train'
test_path = '/content/drive/MyDrive/project/dvdcovers_SNN/data/test'

# %%
from glob import glob
folders = glob('/content/drive/MyDrive/project/dvdcovers_SNN/data/train/*')
folders
# Out:
# ['/content/drive/MyDrive/project/dvdcovers_SNN/data/train/091',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/094',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/093',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/095',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/092',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/004',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/003',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/006',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/007',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/001',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/009',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/008',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/002',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/005',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/015',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/019',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/016',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/010',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/014',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/018',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/013',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/017',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/012',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/011',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/021',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/024',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/020',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/030',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/026',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/023',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/028',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/022',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/027',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/029',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/039',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/035',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/032',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/038',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/037',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/040',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/031',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/033',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/034',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/036',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/044',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/050',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/048',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/047',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/049',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/042',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/046',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/041',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/043',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/045',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/051',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/053',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/056',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/054',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/059',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/057',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/060',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/058',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/055',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/052',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/064',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/066',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/065',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/062',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/063',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/061',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/068',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/069',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/070',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/067',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/077',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/073',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/079',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/072',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/078',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/080',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/075',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/076',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/071',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/074',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/081',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/085',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/090',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/088',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/082',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/084',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/089',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/087',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/086',
#  '/content/drive/MyDrive/project/dvdcovers_SNN/data/train/083']

# %%
#output classes
print(len(folders))
# Out:
# 94

# %% [markdown]
# ## Imports
# All the imports are defined here

# %%
# %matplotlib inline
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %% [markdown]
# ## Helper functions
# Set of helper functions

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %% [markdown]
# ## Configuration Class
# A simple class to manage configuration

# %%
class Config():
    training_dir = "/content/drive/MyDrive/project/dvdcovers_SNN/data/train"
    testing_dir = "/content/drive/MyDrive/project/dvdcovers_SNN/data/test"
    train_batch_size = 64
    train_number_epochs = 100

# %% [markdown]
# ## Custom Dataset Class
# This dataset generates a pair of images. 0 for geniune pair and 1 for imposter pair

# %%
class SiameseNetworkDataset(Dataset):
    
    def __init__(self,imageFolderDataset,transform=None,should_invert=True):
        self.imageFolderDataset = imageFolderDataset    
        self.transform = transform
        self.should_invert = should_invert
        
    def __getitem__(self,index):
        img0_tuple = random.choice(self.imageFolderDataset.imgs)
        #we need to make sure approx 50% of images are in the same class
        should_get_same_class = random.randint(0,1) 
        if should_get_same_class:
            while True:
                #keep looping till the same class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1]==img1_tuple[1]:
                    break
        else:
            while True:
                #keep looping till a different class image is found
                
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1] !=img1_tuple[1]:
                    break

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        if self.should_invert:
            img0 = PIL.ImageOps.invert(img0)
            img1 = PIL.ImageOps.invert(img1)

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(img1_tuple[1]!=img0_tuple[1])],dtype=np.float32))
    
    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %% [markdown]
# ## Using Image Folder Dataset

# %%
folder_dataset = dset.ImageFolder(root=Config.training_dir)

# %%
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

# %% [markdown]
# ## Visualising some of the data
# The top row and the bottom row of any column is one pair. The 0s and 1s correspond to the column of the image.
# 1 indiciates dissimilar, and 0 indicates similar.

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [[1.]
#  [0.]
#  [1.]
#  [0.]
#  [1.]
#  [0.]
#  [1.]
#  [0.]]

# %% [markdown]
# ## Neural Net Definition
# We will use a standard convolutional neural network

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        self.cnn1 = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(1, 4, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(4),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(4, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),


            nn.ReflectionPad2d(1),
            nn.Conv2d(8, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),


        )

        self.fc1 = nn.Sequential(
            nn.Linear(8*100*100, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 5))

    def forward_once(self, x):
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        return output1, output2

# %% [markdown]
# ## Contrastive Loss

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2, keepdim = True)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# ## Training Time!

# %%
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
net = SiameseNetwork()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(),lr = 0.0005 )

# %%
counter = []
loss_history = [] 
iteration_number= 0

# %%
for epoch in range(0,Config.train_number_epochs):
    for i, data in enumerate(train_dataloader,0):
        img0, img1 , label = data
        #img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
        img0, img1 , label = img0, img1, label
        optimizer.zero_grad()
        output1,output2 = net(img0,img1)
        loss_contrastive = criterion(output1,output2,label)
        loss_contrastive.backward()
        optimizer.step()
        if i %10 == 0 :
            print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
            iteration_number +=10
            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())
show_plot(counter,loss_history)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch number 0
#  Current loss 1.4825736284255981
#
# Epoch number 0
#  Current loss 7.934499263763428
#
# Epoch number 1
#  Current loss 3.8197011947631836
#
# Epoch number 1
#  Current loss 2.315786123275757
#
# Epoch number 2
#  Current loss 2.820939302444458
#
# Epoch number 2
#  Current loss 1.473652720451355
#
# Epoch number 3
#  Current loss 1.098927617073059
#
# Epoch number 3
#  Current loss 1.4286693334579468
#
# Epoch number 4
#  Current loss 1.2714937925338745
#
# Epoch number 4
#  Current loss 0.9731624126434326
#
# Epoch number 5
#  Current loss 1.3552637100219727
#
# Epoch number 5
#  Current loss 1.273908257484436
#
# Epoch number 6
#  Current loss 0.7386553287506104
#
# Epoch number 6
#  Current loss 1.1378217935562134
#
# Epoch number 7
#  Current loss 0.7886017560958862
#
# Epoch number 7
#  Current loss 1.0723356008529663
#
# Epoch number 8
#  Current loss 0.9118175506591797
#
# Epoch number 8
#  Current loss 0.9014787673950195
#
# Epoch number 9
#  Current loss 0.6519639492034912
#
# Epoch number 9
#  Current loss 0.6428991556167603
#
# Epoch number 10
#  Current loss 0.3102491497993469
#
# Epoch number 10
#  Current loss 0.7306162118911743
#
# Epoch number 11
#  Current loss 0.9003412127494812
#
# Epoch number 11
#  Current loss 0.2861737906932831
#
# Epoch number 12
#  Current loss 0.42912861704826355
#
# Epoch number 12
#  Current loss 0.3871428668498993
#
# Epoch number 13
#  Current loss 0.4442751705646515
#
# Epoch number 13
#  Current loss 0.41019999980926514
#
# Epoch number 14
#  Current loss 0.37654435634613037
#
# Epoch number 14
#  Current loss 0.43041402101516724
#
# Epoch number 15
#  Current loss 1.0011154413223267
#
# Epoch number 15
#  Current loss 0.4779297709465027
#
# Epoch number 16
#  Current loss 0.292599081993103
#
# Epoch number 16
#  Current loss 0.36626356840133667
#
# Epoch number 17
#  Current loss 0.34748923778533936
#
# Epoch number 17
#  Current loss 0.47270703315734863
#
# Epoch number 18
#  Current loss 0.30933472514152527
#
# Epoch number 18
#  Current loss 0.42175865173339844
#
# Epoch number 19
#  Current loss 0.27716681361198425
#
# Epoch number 19
#  Current loss 0.21511253714561462
#
# Epoch number 20
#  Current loss 0.2765408754348755
#
# Epoch number 20
#  Current loss 0.33440908789634705
#
# Epoch number 21
#  Current loss 0.31030505895614624
#
# Epoch number 21
#  Current loss 0.280753493309021
#
# Epoch number 22
#  Current loss 0.252535879611969
#
# Epoch number 22
#  Current loss 0.2036527544260025
#
# Epoch number 23
#  Current loss 0.20891374349594116
#
# Epoch number 23
#  Current loss 0.22061306238174438
#
# Epoch number 24
#  Current loss 0.2952820956707001
#
# Epoch number 24
#  Current loss 0.26473504304885864
#
# Epoch number 25
#  Current loss 0.2605561316013336
#
# Epoch number 25
#  Current loss 0.20415307581424713
#
# Epoch number 26
#  Current loss 0.19740422070026398
#
# Epoch number 26
#  Current loss 0.33360764384269714
#
# Epoch number 27
#  Current loss 0.2350187599658966
#
# Epoch number 27
#  Current loss 0.15426455438137054
#
# Epoch number 28
#  Current loss 0.14694900810718536
#
# Epoch number 28
#  Current loss 0.20811256766319275
#
# Epoch number 29
#  Current loss 0.16640222072601318
#
# Epoch number 29
#  Current loss 0.21914467215538025
#
# Epoch number 30
#  Current loss 0.10986655950546265
#
# Epoch number 30
#  Current loss 0.11110566556453705
#
# Epoch number 31
#  Current loss 0.1450895518064499
#
# Epoch number 31
#  Current loss 0.18216067552566528
#
# Epoch number 32
#  Current loss 0.12993194162845612
#
# Epoch number 32
#  Current loss 0.18657803535461426
#
# Epoch number 33
#  Current loss 0.24322596192359924
#
# Epoch number 33
#  Current loss 0.18789298832416534
#
# Epoch number 34
#  Current loss 0.20302441716194153
#
# Epoch number 34
#  Current loss 0.20090153813362122
#
# Epoch number 35
#  Current loss 0.12520655989646912
#
# Epoch number 35
#  Current loss 0.1368223875761032
#
# Epoch number 36
#  Current loss 0.2106328159570694
#
# Epoch number 36
#  Current loss 0.23558545112609863
#
# Epoch number 37
#  Current loss 0.19630396366119385
#
# Epoch number 37
#  Current loss 0.16741713881492615
#
# Epoch number 38
#  Current loss 0.1834193468093872
#
# Epoch number 38
#  Current loss 0.17100660502910614
#
# Epoch number 39
#  Current loss 0.20073729753494263
#
# Epoch number 39
#  Current loss 0.13153283298015594
#
# Epoch number 40
#  Current loss 0.09551737457513809
#
# Epoch number 40
#  Current loss 0.15350845456123352
#
# Epoch number 41
#  Current loss 0.11373083293437958
#
# Epoch number 41
#  Current loss 0.1975235939025879
#
# Epoch number 42
#  Current loss 0.1184137761592865
#
# Epoch number 42
#  Current loss 0.09982791543006897
#
# Epoch number 43
#  Current loss 0.11816665530204773
#
# Epoch number 43
#  Current loss 0.12453493475914001
#
# Epoch number 44
#  Current loss 0.11409290134906769
#
# Epoch number 44
#  Current loss 0.10604317486286163
#
# Epoch number 45
#  Current loss 0.1507420539855957
#
# Epoch number 45
#  Current loss 0.12006662040948868
#
# Epoch number 46
#  Current loss 0.11801997572183609
#
# Epoch number 46
#  Current loss 0.10627539455890656
#
# Epoch number 47
#  Current loss 0.06989527493715286
#
# Epoch number 47
#  Current loss 0.11133711040019989
#
# Epoch number 48
#  Current loss 0.15003764629364014
#
# Epoch number 48
#  Current loss 0.10237949341535568
#
# Epoch number 49
#  Current loss 0.07942741364240646
#
# Epoch number 49
#  Current loss 0.11994612216949463

# %% [markdown]
# ## Some simple testing
# The last 3 subjects were held out from the training, and will be used to test. The Distance between each image pair denotes the degree of similarity the model found between the two images. Less means it found more similar, while higher values indicate it found them to be dissimilar.

# %%
folder_dataset_test = dset.ImageFolder(root=Config.testing_dir)
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

test_dataloader = DataLoader(siamese_dataset,num_workers=6,batch_size=1,shuffle=True)
dataiter = iter(test_dataloader)
x0,_,_ = next(dataiter)

for i in range(10):
    _,x1,label2 = next(dataiter)
    concatenated = torch.cat((x0,x1),0)
    
    #output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    output1,output2 = net(Variable(x0),Variable(x1))
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}'.format(euclidean_distance.item()))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
